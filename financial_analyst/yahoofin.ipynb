# %%
import yfinance as yf
import pandas as pd
import numpy as np

# %%
dir(yf)
# Out:
# ['AsyncWebSocket',
#  'EquityQuery',
#  'FundQuery',
#  'Industry',
#  'Lookup',
#  'Market',
#  'PREDEFINED_SCREENER_QUERIES',
#  'Search',
#  'Sector',
#  'Ticker',
#  'Tickers',
#  'WebSocket',
#  'YfData',
#  '_NOTSET',
#  '__all__',
#  '__author__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'cache',
#  'const',
#  'data',
#  'domain',
#  'download',
#  'enable_debug_mode',
#  'exceptions',
#  'live',
#  'lookup',
#  'multi',
#  'pricing_pb2',
#  'scrapers',
#  'screen',
#  'screener',
#  'search',
#  'set_config',
#  'set_tz_cache_location',
#  'shared',
#  'ticker',
#  'tickers',
#  'utils',
#  'version',
#  'warnings']

# %%
#ticker
tdg = yf.Ticker('bot.ax')
tdg.info
# Out:
# {'address1': '41 – 47 Colin Street',
#  'address2': 'Suite 3',
#  'city': 'West Perth',
#  'state': 'WA',
#  'zip': '6005',
#  'country': 'Australia',
#  'phone': '61 8 6555 2945',
#  'fax': '61 8 6210 1153',
#  'website': 'https://www.botanixpharma.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
#  'longBusinessSummary': 'Botanix Pharmaceuticals Limited engages in the research and development of dermatology and antimicrobial products in Australia and the United States. Its product pipeline includes Sofpironium Bromide, a drug in development for the treatment of primary axillary hyperhidrosis that has completed Phase 3 clinical programs; BTX 1503, a transdermal gel formulation for the treatment of serious acne in adults and teenagers that has completed Phase II clinical trials; BTX 1801, which has completed Phase IIa clinical trials for the treatment of staphylococcus aureus and methicillin resistant staphylococcus aureus; BTX 1702 that is in Phase II clinical trials for the treatment of papulopustular rosacea; and BTX 1204A for the treatment of atopic dermatitis. Botanix Pharmaceuticals Limited was incorporated in 1984 and is based in West Perth, Australia.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Vincent P. Ippolito',
#    'age': 65,
#    'title': 'MD & Executive Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'totalPay': 1073442,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Howie  McKibbon',
#    'title': 'Chief Executive Officer',
#    'fiscalYear': 2025,
#    'totalPay': 959196,
#    'exercisedValue': 2775241,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Graeme  Morissey',
#    'title': 'Chief Financial Officer',
#    'fiscalYear': 2025,
#    'totalPay': 125000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Lesovitz',
#    'title': 'Chief Financial Officer of United States of America',
#    'fiscalYear': 2025,
#    'totalPay': 641191,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Patricia S. Walker M.D., Ph.D.',
#    'age': 65,
#    'title': 'Chief Medical Adviser & Non-Executive Director',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Boris  Meyerson Ph.D.',
#    'title': 'Chief Business Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David  Morgan',
#    'title': 'Head of Corporate Affairs',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevin  Wojciechowski',
#    'title': 'Head of HCP Marketing & Sales Training',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Darin  Van Arsdale',
#    'title': 'Director of Sales Operations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 10,
#  'boardRisk': 9,
#  'compensationRisk': 9,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 9,
#  'governanceEpochDate': 1756684800,
#  'compensationAsOfEpochDate': 1767139200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.11,
#  'open': 0.11,
#  'dayLow': 0.11,
#  'dayHigh': 0.127,
#  'regularMarketPreviousClose': 0.11,
#  'regularMarketOpen': 0.11,
#  'regularMarketDayLow': 0.11,
#  'regularMarketDayHigh': 0.127,
#  'payoutRatio': 0.0,
#  'beta': 0.918,
#  'forwardPE': 2.0833335,
#  'volume': 9538210,
#  'regularMarketVolume': 9538210,
#  'averageVolume': 15046108,
#  'averageVolume10days': 11154029,
#  'averageDailyVolume10Day': 11154029,
#  'bid': 0.12,
#  'ask': 0.125,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 245166256,
#  'fiftyTwoWeekLow': 0.105,
#  'fiftyTwoWeekHigh': 0.535,
#  'priceToSalesTrailing12Months': 42.348972,
#  'fiftyDayAverage': 0.1519,
#  'twoHundredDayAverage': 0.342225,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'AUD',
#  'tradeable': False,
#  'enterpriseValue': 181392016,
#  'profitMargins': 0.0,
#  'floatShares': 1717633159,
#  'sharesOutstanding': 1961330048,
#  'heldPercentInsiders': 0.122889996,
#  'heldPercentInstitutions': 0.22769,
#  'impliedSharesOutstanding': 1961330048,
#  'bookValue': 0.041,
#  'priceToBook': 3.0487804,
#  'lastFiscalYearEnd': 1751241600,
#  'nextFiscalYearEnd': 1782777600,
#  'mostRecentQuarter': 1751241600,
#  'netIncomeToCommon': -86396184,
#  'trailingEps': -0.05,
#  'forwardEps': 0.06,
#  'lastSplitFactor': '1:3',
#  'lastSplitDate': 1466035200,
#  'enterpriseToRevenue': 31.333,
#  'enterpriseToEbitda': -2.249,
#  '52WeekChange': -0.6987952,
#  'SandP52WeekChange': 0.16885936,
#  'quoteType': 'EQUITY',
#  'currentPrice': 0.125,
#  'targetHighPrice': 2.0,
#  'targetLowPrice': 0.27,
#  'targetMeanPrice': 0.89333,
#  'targetMedianPrice': 0.41,
#  'recommendationMean': 1.66667,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 3,
#  'totalCash': 64966580,
#  'totalCashPerShare': 0.033,
#  'ebitda': -80650936,
#  'totalDebt': 1217759,
#  'quickRatio': 2.735,
#  'currentRatio': 3.996,
#  'totalRevenue': 5789190,
#  'debtToEquity': 1.498,
#  'revenuePerShare': 0.003,
#  'returnOnAssets': -0.42905998,
#  'returnOnEquity': -0.90928,
#  'grossProfits': 2017687,
#  'freeCashflow': -38580200,
#  'operatingCashflow': -78584744,
#  'revenueGrowth': 2.199,
#  'grossMargins': 0.34853,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': -9.41374,
#  'financialCurrency': 'AUD',
#  'symbol': 'BOT.AX',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'marketState': 'CLOSED',
#  'regularMarketChangePercent': 13.636364,
#  'regularMarketPrice': 0.125,
#  'corporateActions': [],
#  'regularMarketTime': 1757657431,
#  'exchange': 'ASX',
#  'messageBoardId': 'finmb_324672225',
#  'exchangeTimezoneName': 'Australia/Sydney',
#  'exchangeTimezoneShortName': 'AEST',
#  'gmtOffSetMilliseconds': 36000000,
#  'market': 'au_market',
#  'esgPopulated': False,
#  'shortName': 'BOTANIX FPO [BOT]',
#  'longName': 'Botanix Pharmaceuticals Limited',
#  'averageAnalystRating': '1.7 - Buy',
#  'cryptoTradeable': False,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 570409200000,
#  'regularMarketChange': 0.015000001,
#  'regularMarketDayRange': '0.11 - 0.127',
#  'fullExchangeName': 'ASX',
#  'averageDailyVolume3Month': 15046108,
#  'fiftyTwoWeekLowChange': 0.020000003,
#  'fiftyTwoWeekLowChangePercent': 0.19047622,
#  'fiftyTwoWeekRange': '0.105 - 0.535',
#  'fiftyTwoWeekHighChange': -0.41000003,
#  'fiftyTwoWeekHighChangePercent': -0.76635516,
#  'fiftyTwoWeekChangePercent': -69.87952,
#  'earningsTimestampStart': 1753786740,
#  'earningsTimestampEnd': 1754308800,
#  'earningsCallTimestampStart': 1726533000,
#  'earningsCallTimestampEnd': 1726533000,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': -0.05,
#  'epsForward': 0.06,
#  'epsCurrentYear': -0.0305,
#  'priceEpsCurrentYear': -4.0983605,
#  'fiftyDayAverageChange': -0.026899993,
#  'fiftyDayAverageChangePercent': -0.17709015,
#  'twoHundredDayAverageChange': -0.21722499,
#  'twoHundredDayAverageChangePercent': -0.6347432,
#  'sourceInterval': 20,
#  'exchangeDataDelayedBy': 20,
#  'trailingPegRatio': None}

# %%
data = tdg.history()
data.head()
# Out:
#                             Open    High    Low  Close   Volume  Dividends  \
# Date
# 2025-08-12 00:00:00+10:00  0.145  0.1600  0.145  0.160  9759244        0.0
# 2025-08-13 00:00:00+10:00  0.155  0.1600  0.150  0.155  3897637        0.0
# 2025-08-14 00:00:00+10:00  0.150  0.1550  0.145  0.145  5982047        0.0
# 2025-08-15 00:00:00+10:00  0.150  0.1525  0.145  0.150  3581587        0.0
# 2025-08-18 00:00:00+10:00  0.150  0.1550  0.145  0.150  6081168        0.0
#
#                            Stock Splits
# Date
# 2025-08-12 00:00:00+10:00           0.0
# 2025-08-13 00:00:00+10:00           0.0
# 2025-08-14 00:00:00+10:00           0.0
# 2025-08-15 00:00:00+10:00           0.0
# 2025-08-18 00:00:00+10:00           0.0

# %%
data = tdg.history(interval='1m', start='2025-08-26', end='2025-08-31')
data.head()
# Out:
#                             Open   High    Low  Close  Volume  Dividends  \
# Datetime
# 2025-08-26 10:00:00+10:00  0.160  0.160  0.160  0.160       0        0.0
# 2025-08-26 10:01:00+10:00  0.160  0.160  0.157  0.160  398294        0.0
# 2025-08-26 10:02:00+10:00  0.160  0.160  0.160  0.160  232986        0.0
# 2025-08-26 10:04:00+10:00  0.160  0.160  0.160  0.160  413415        0.0
# 2025-08-26 10:12:00+10:00  0.157  0.157  0.157  0.157   20000        0.0
#
#                            Stock Splits
# Datetime
# 2025-08-26 10:00:00+10:00           0.0
# 2025-08-26 10:01:00+10:00           0.0
# 2025-08-26 10:02:00+10:00           0.0
# 2025-08-26 10:04:00+10:00           0.0
# 2025-08-26 10:12:00+10:00           0.0

# %%
data = yf.download(['goog','meta'],period='1mo')
data.head()
# Out:
# C:\Users\x_gau\AppData\Local\Temp\ipykernel_3776\798395259.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(['goog','meta'],period='1mo')
# [*********************100%***********************]  2 of 2 completed
# Price            Close                    High                     Low  \
# Ticker            GOOG        META        GOOG        META        GOOG
# Date
# 2025-08-13  202.848694  780.080017  205.246545  795.460022  198.462615
# 2025-08-14  203.638000  782.130005  205.236563  787.809998  202.144325
# 2025-08-15  204.727020  785.229980  207.144857  796.250000  201.904546
# 2025-08-18  204.107559  767.369995  205.955913  775.809998  203.228355
# 2025-08-19  202.309189  751.479980  204.107569  767.169983  200.750569
#
# Price                         Open                Volume
# Ticker            META        GOOG        META      GOOG      META
# Date
# 2025-08-13  778.229980  204.796949  791.150024  19573000   8811800
# 2025-08-14  772.510010  202.379116  777.880005  17777100   8116200
# 2025-08-15  780.820007  204.537187  784.150024  21111400  13375400
# 2025-08-18  756.559998  204.886877  775.090027  13000200  16513700
# 2025-08-19  749.359985  203.722919  767.119995  13476600  12286700

# %%
tickers = yf.Tickers('nasdaq')
tickers.tickers
# Out:
# {'NASDAQ': yfinance.Ticker object <NASDAQ>}

# %%
ticker = yf.Ticker('bot.ax')
ticker.info
# Out:
# {'address1': '41 – 47 Colin Street',
#  'address2': 'Suite 3',
#  'city': 'West Perth',
#  'state': 'WA',
#  'zip': '6005',
#  'country': 'Australia',
#  'phone': '61 8 6555 2945',
#  'fax': '61 8 6210 1153',
#  'website': 'https://www.botanixpharma.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
#  'longBusinessSummary': 'Botanix Pharmaceuticals Limited engages in the research and development of dermatology and antimicrobial products in Australia and the United States. Its product pipeline includes Sofpironium Bromide, a drug in development for the treatment of primary axillary hyperhidrosis that has completed Phase 3 clinical programs; BTX 1503, a transdermal gel formulation for the treatment of serious acne in adults and teenagers that has completed Phase II clinical trials; BTX 1801, which has completed Phase IIa clinical trials for the treatment of staphylococcus aureus and methicillin resistant staphylococcus aureus; BTX 1702 that is in Phase II clinical trials for the treatment of papulopustular rosacea; and BTX 1204A for the treatment of atopic dermatitis. Botanix Pharmaceuticals Limited was incorporated in 1984 and is based in West Perth, Australia.',
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Vincent P. Ippolito',
#    'age': 65,
#    'title': 'MD & Executive Chairman',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'totalPay': 1073442,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Howie  McKibbon',
#    'title': 'Chief Executive Officer',
#    'fiscalYear': 2025,
#    'totalPay': 959196,
#    'exercisedValue': 2775241,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Graeme  Morissey',
#    'title': 'Chief Financial Officer',
#    'fiscalYear': 2025,
#    'totalPay': 125000,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Lesovitz',
#    'title': 'Chief Financial Officer of United States of America',
#    'fiscalYear': 2025,
#    'totalPay': 641191,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Patricia S. Walker M.D., Ph.D.',
#    'age': 65,
#    'title': 'Chief Medical Adviser & Non-Executive Director',
#    'yearBorn': 1959,
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dr. Boris  Meyerson Ph.D.',
#    'title': 'Chief Business Officer',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. David  Morgan',
#    'title': 'Head of Corporate Affairs',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Kevin  Wojciechowski',
#    'title': 'Head of HCP Marketing & Sales Training',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Darin  Van Arsdale',
#    'title': 'Director of Sales Operations',
#    'fiscalYear': 2025,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 10,
#  'boardRisk': 9,
#  'compensationRisk': 9,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 9,
#  'governanceEpochDate': 1756684800,
#  'compensationAsOfEpochDate': 1767139200,
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 0.11,
#  'open': 0.11,
#  'dayLow': 0.11,
#  'dayHigh': 0.127,
#  'regularMarketPreviousClose': 0.11,
#  'regularMarketOpen': 0.11,
#  'regularMarketDayLow': 0.11,
#  'regularMarketDayHigh': 0.127,
#  'payoutRatio': 0.0,
#  'beta': 0.918,
#  'forwardPE': 2.0833335,
#  'volume': 9538210,
#  'regularMarketVolume': 9538210,
#  'averageVolume': 15046108,
#  'averageVolume10days': 11154029,
#  'averageDailyVolume10Day': 11154029,
#  'bid': 0.12,
#  'ask': 0.125,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 245166256,
#  'fiftyTwoWeekLow': 0.105,
#  'fiftyTwoWeekHigh': 0.535,
#  'priceToSalesTrailing12Months': 42.348972,
#  'fiftyDayAverage': 0.1519,
#  'twoHundredDayAverage': 0.342225,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'AUD',
#  'tradeable': False,
#  'enterpriseValue': 181392016,
#  'profitMargins': 0.0,
#  'floatShares': 1717633159,
#  'sharesOutstanding': 1961330048,
#  'heldPercentInsiders': 0.122889996,
#  'heldPercentInstitutions': 0.22769,
#  'impliedSharesOutstanding': 1961330048,
#  'bookValue': 0.041,
#  'priceToBook': 3.0487804,
#  'lastFiscalYearEnd': 1751241600,
#  'nextFiscalYearEnd': 1782777600,
#  'mostRecentQuarter': 1751241600,
#  'netIncomeToCommon': -86396184,
#  'trailingEps': -0.05,
#  'forwardEps': 0.06,
#  'lastSplitFactor': '1:3',
#  'lastSplitDate': 1466035200,
#  'enterpriseToRevenue': 31.333,
#  'enterpriseToEbitda': -2.249,
#  '52WeekChange': -0.6987952,
#  'SandP52WeekChange': 0.16885936,
#  'quoteType': 'EQUITY',
#  'currentPrice': 0.125,
#  'targetHighPrice': 2.0,
#  'targetLowPrice': 0.27,
#  'targetMeanPrice': 0.89333,
#  'targetMedianPrice': 0.41,
#  'recommendationMean': 1.66667,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 3,
#  'totalCash': 64966580,
#  'totalCashPerShare': 0.033,
#  'ebitda': -80650936,
#  'totalDebt': 1217759,
#  'quickRatio': 2.735,
#  'currentRatio': 3.996,
#  'totalRevenue': 5789190,
#  'debtToEquity': 1.498,
#  'revenuePerShare': 0.003,
#  'returnOnAssets': -0.42905998,
#  'returnOnEquity': -0.90928,
#  'grossProfits': 2017687,
#  'freeCashflow': -38580200,
#  'operatingCashflow': -78584744,
#  'revenueGrowth': 2.199,
#  'grossMargins': 0.34853,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': -9.41374,
#  'financialCurrency': 'AUD',
#  'symbol': 'BOT.AX',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'corporateActions': [],
#  'regularMarketTime': 1757657431,
#  'exchange': 'ASX',
#  'messageBoardId': 'finmb_324672225',
#  'exchangeTimezoneName': 'Australia/Sydney',
#  'exchangeTimezoneShortName': 'AEST',
#  'gmtOffSetMilliseconds': 36000000,
#  'market': 'au_market',
#  'esgPopulated': False,
#  'longName': 'Botanix Pharmaceuticals Limited',
#  'regularMarketChangePercent': 13.636364,
#  'regularMarketPrice': 0.125,
#  'marketState': 'CLOSED',
#  'regularMarketChange': 0.015000001,
#  'regularMarketDayRange': '0.11 - 0.127',
#  'fullExchangeName': 'ASX',
#  'averageDailyVolume3Month': 15046108,
#  'fiftyTwoWeekLowChange': 0.020000003,
#  'fiftyTwoWeekLowChangePercent': 0.19047622,
#  'fiftyTwoWeekRange': '0.105 - 0.535',
#  'fiftyTwoWeekHighChange': -0.41000003,
#  'fiftyTwoWeekHighChangePercent': -0.76635516,
#  'fiftyTwoWeekChangePercent': -69.87952,
#  'earningsTimestampStart': 1753786740,
#  'earningsTimestampEnd': 1754308800,
#  'earningsCallTimestampStart': 1726533000,
#  'earningsCallTimestampEnd': 1726533000,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': -0.05,
#  'epsForward': 0.06,
#  'epsCurrentYear': -0.0305,
#  'priceEpsCurrentYear': -4.0983605,
#  'fiftyDayAverageChange': -0.026899993,
#  'fiftyDayAverageChangePercent': -0.17709015,
#  'twoHundredDayAverageChange': -0.21722499,
#  'twoHundredDayAverageChangePercent': -0.6347432,
#  'sourceInterval': 20,
#  'exchangeDataDelayedBy': 20,
#  'averageAnalystRating': '1.7 - Buy',
#  'cryptoTradeable': False,
#  'shortName': 'BOTANIX FPO [BOT]',
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 570409200000,
#  'trailingPegRatio': None}

# %%
#free cash flow
ticker.info['freeCashflow']
# Out:
# -38580200

# %%
# Debt, Equity, Beta, tax rate, market return
beta = ticker.info['beta']
tax_rate_us = 0.15
market_return = 0.10
totaldebt = ticker.info['totalDebt']
equity = totaldebt / ticker.info['debtToEquity']
equity
marketcap = ticker.info['marketCap']
equity
# Out:
# 812923.2309746329

# %%
ticker.info['debtToEquity']
# Out:
# 1.498

# %%
# Ten Year Treasury Rate
risk_free_rate = yf.Ticker('^TNX').info['previousClose']/100
risk_free_rate
# Out:
# 0.04011

# %%
#cost of equity

cost_of_equity = risk_free_rate + beta * (market_return - risk_free_rate)
cost_of_equity
# Out:
# 0.09508902000000001

# %%
#cost of debt
cost_of_debt = 0.05

# %%
#wacc = ((equity/equity+totaldebt) * cost_of_equity) + ((totaldebt/equity+totaldebt) * cost_of_debt) * (1-tax_rate_us)
wacc = (equity/(equity+totaldebt))*cost_of_equity + (totaldebt / (equity+totaldebt)) * cost_of_debt * (1-tax_rate_us)

wacc
# Out:
# 0.06355244995996798

# %%
cashflow = ticker.cashflow

cashflow
# Out:
#                                                    2024-06-30  2023-06-30  \
# Free Cash Flow                                    -26126748.0 -19127785.0
# Repurchase Of Capital Stock                        -5756644.0  -1438359.0
# Repayment Of Debt                                         NaN  -1849236.0
# Issuance Of Debt                                          NaN   1849237.0
# Issuance Of Capital Stock                         100854964.0  23590350.0
# Capital Expenditure                               -17999467.0  -7053721.0
# Interest Paid Supplemental Data                           NaN     80020.0
# End Cash Position                                  79308130.0  10250395.0
# Beginning Cash Position                            10250395.0   7285653.0
# Effect Of Exchange Rate Changes                       86163.0     62949.0
# Changes In Cash                                    68971572.0   2901793.0
# Financing Cash Flow                                95098320.0  22029578.0
# Cash Flow From Continuing Financing Activities     95098320.0  22029578.0
# Net Other Financing Charges                               NaN   -122414.0
# Net Common Stock Issuance                          95098320.0  22151991.0
# Common Stock Payments                              -5756644.0  -1438359.0
# Common Stock Issuance                             100854964.0  23590350.0
# Net Issuance Payments Of Debt                             NaN         1.0
# Net Long Term Debt Issuance                               NaN         1.0
# Long Term Debt Payments                                   NaN  -1849236.0
# Long Term Debt Issuance                                   NaN   1849237.0
# Investing Cash Flow                               -17999467.0  -7053721.0
# Cash Flow From Continuing Investing Activities    -17999467.0  -7053721.0
# Net Intangibles Purchase And Sale                 -17886767.0  -7046149.0
# Purchase Of Intangibles                           -17886767.0  -7046149.0
# Net PPE Purchase And Sale                           -112700.0     -7572.0
# Purchase Of PPE                                     -112700.0     -7572.0
# Cash Flowsfromusedin Operating Activities Direct   -8127281.0 -12074064.0
# Interest Received Direct                              75721.0     65215.0
# Interest Paid Direct                                      NaN    -80020.0
# Classesof Cash Payments                            -9266538.0 -16247096.0
# Paymentsto Suppliersfor Goodsand Services          -9266538.0 -16247096.0
# Classesof Cash Receiptsfrom Operating Activities    1063536.0   4187837.0
# Other Cash Receiptsfrom Operating Activities              NaN   3669439.0
# Receiptsfrom Customers                              1063536.0    518398.0
#
#                                                   2022-06-30  2021-06-30
# Free Cash Flow                                   -14105926.0  -2976304.0
# Repurchase Of Capital Stock                              NaN         NaN
# Repayment Of Debt                                        NaN         NaN
# Issuance Of Debt                                         NaN         NaN
# Issuance Of Capital Stock                                NaN         NaN
# Capital Expenditure                               -2921870.0     -8281.0
# Interest Paid Supplemental Data                      37440.0     55941.0
# End Cash Position                                  7285653.0  21554906.0
# Beginning Cash Position                           21554906.0  24645185.0
# Effect Of Exchange Rate Changes                     -10916.0     11527.0
# Changes In Cash                                  -14258337.0  -3101806.0
# Financing Cash Flow                                -152411.0   -125502.0
# Cash Flow From Continuing Financing Activities     -152411.0   -125502.0
# Net Other Financing Charges                        -152411.0   -125502.0
# Net Common Stock Issuance                                NaN         NaN
# Common Stock Payments                                    NaN         NaN
# Common Stock Issuance                                    NaN         NaN
# Net Issuance Payments Of Debt                            NaN         NaN
# Net Long Term Debt Issuance                              NaN         NaN
# Long Term Debt Payments                                  NaN         NaN
# Long Term Debt Issuance                                  NaN         NaN
# Investing Cash Flow                               -2921870.0     -8281.0
# Cash Flow From Continuing Investing Activities    -2921870.0     -8281.0
# Net Intangibles Purchase And Sale                 -2914662.0         NaN
# Purchase Of Intangibles                           -2914662.0         NaN
# Net PPE Purchase And Sale                            -7208.0     -8281.0
# Purchase Of PPE                                      -7208.0     -8281.0
# Cash Flowsfromusedin Operating Activities Direct -11184056.0  -2968023.0
# Interest Received Direct                             37374.0    103788.0
# Interest Paid Direct                                -37440.0    -55941.0
# Classesof Cash Payments                          -13938825.0  -9903068.0
# Paymentsto Suppliersfor Goodsand Services        -13938825.0  -9903068.0
# Classesof Cash Receiptsfrom Operating Activities   2754835.0   6887198.0
# Other Cash Receiptsfrom Operating Activities       2754835.0   6887198.0
# Receiptsfrom Customers                                   NaN         NaN

# %%
# Free Cash Flow Estimate for future

growth_rate = 0.02
ev_to_ebitda = ticker.info['enterpriseToEbitda']
free_cash_flow = ticker.info['freeCashflow']
terminal_period = 5
free_cash_flow
teminal_value_fcf = free_cash_flow*(1+growth_rate)**terminal_period

#cashflow.index.tolist()
#len(cashflow.columns)
ending_fcf = cashflow.loc['Free Cash Flow'].iloc[0]
beginning_fcf = cashflow.loc['Free Cash Flow'].iloc[4]

terminal_period = 4
while pd.isna(beginning_fcf):
    beginning_fcf = cashflow.loc['Free Cash Flow'].iloc[terminal_period-1]
    terminal_period -= 1

beginning_fcf

fcf_cagr = (ending_fcf/beginning_fcf)**(1/terminal_period) - 1
fcf_cagr

future_fcf = ending_fcf*(1+fcf_cagr)**(5)
future_fcf
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[34], line 13
#      10 #cashflow.index.tolist()
#      11 #len(cashflow.columns)
#      12 ending_fcf = cashflow.loc['Free Cash Flow'].iloc[0]
# ---> 13 beginning_fcf = cashflow.loc['Free Cash Flow'].iloc[4]
#      15 terminal_period = 4
#      16 while pd.isna(beginning_fcf):
#
# File c:\Users\x_gau\source\repos\agentic\langchain\tutorials\finance-app\venv\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\x_gau\source\repos\agentic\langchain\tutorials\finance-app\venv\Lib\site-packages\pandas\core\indexing.py:1752, in _iLocIndexer._getitem_axis(self, key, axis)
#    1749     raise TypeError("Cannot index by location index with a non-integer key")
#    1751 # validate the location
# -> 1752 self._validate_integer(key, axis)
#    1754 return self.obj._ixs(key, axis=axis)
#
# File c:\Users\x_gau\source\repos\agentic\langchain\tutorials\finance-app\venv\Lib\site-packages\pandas\core\indexing.py:1685, in _iLocIndexer._validate_integer(self, key, axis)
#    1683 len_axis = len(self.obj._get_axis(axis))
#    1684 if key >= len_axis or key < -len_axis:
# -> 1685     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %%
# income statement

income_statement = ticker.income_stmt
income_statement
# Out:
#                                                       2024-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  2.410000e-01
# Normalized EBITDA                                   1.346610e+11
# Net Income From Continuing Operation Net Minori...  9.373600e+10
# Reconciled Depreciation                             1.144500e+10
# Reconciled Cost Of Revenue                          2.103520e+11
# EBITDA                                              1.346610e+11
# EBIT                                                1.232160e+11
# Net Interest Income                                          NaN
# Interest Expense                                             NaN
# Interest Income                                              NaN
# Normalized Income                                   9.373600e+10
# Net Income From Continuing And Discontinued Ope...  9.373600e+10
# Total Expenses                                      2.678190e+11
# Total Operating Income As Reported                  1.232160e+11
# Diluted Average Shares                              1.540810e+10
# Basic Average Shares                                1.534378e+10
# Diluted EPS                                         6.080000e+00
# Basic EPS                                           6.110000e+00
# Diluted NI Availto Com Stockholders                 9.373600e+10
# Net Income Common Stockholders                      9.373600e+10
# Net Income                                          9.373600e+10
# Net Income Including Noncontrolling Interests       9.373600e+10
# Net Income Continuous Operations                    9.373600e+10
# Tax Provision                                       2.974900e+10
# Pretax Income                                       1.234850e+11
# Other Income Expense                                2.690000e+08
# Other Non Operating Income Expenses                 2.690000e+08
# Net Non Operating Interest Income Expense                    NaN
# Interest Expense Non Operating                               NaN
# Interest Income Non Operating                                NaN
# Operating Income                                    1.232160e+11
# Operating Expense                                   5.746700e+10
# Research And Development                            3.137000e+10
# Selling General And Administration                  2.609700e+10
# Gross Profit                                        1.806830e+11
# Cost Of Revenue                                     2.103520e+11
# Total Revenue                                       3.910350e+11
# Operating Revenue                                   3.910350e+11
#
#                                                       2023-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.470000e-01
# Normalized EBITDA                                   1.258200e+11
# Net Income From Continuing Operation Net Minori...  9.699500e+10
# Reconciled Depreciation                             1.151900e+10
# Reconciled Cost Of Revenue                          2.141370e+11
# EBITDA                                              1.258200e+11
# EBIT                                                1.143010e+11
# Net Interest Income                                -1.830000e+08
# Interest Expense                                    3.933000e+09
# Interest Income                                     3.750000e+09
# Normalized Income                                   9.699500e+10
# Net Income From Continuing And Discontinued Ope...  9.699500e+10
# Total Expenses                                      2.689840e+11
# Total Operating Income As Reported                  1.143010e+11
# Diluted Average Shares                              1.581255e+10
# Basic Average Shares                                1.574423e+10
# Diluted EPS                                         6.130000e+00
# Basic EPS                                           6.160000e+00
# Diluted NI Availto Com Stockholders                 9.699500e+10
# Net Income Common Stockholders                      9.699500e+10
# Net Income                                          9.699500e+10
# Net Income Including Noncontrolling Interests       9.699500e+10
# Net Income Continuous Operations                    9.699500e+10
# Tax Provision                                       1.674100e+10
# Pretax Income                                       1.137360e+11
# Other Income Expense                               -5.650000e+08
# Other Non Operating Income Expenses                -5.650000e+08
# Net Non Operating Interest Income Expense          -1.830000e+08
# Interest Expense Non Operating                      3.933000e+09
# Interest Income Non Operating                       3.750000e+09
# Operating Income                                    1.143010e+11
# Operating Expense                                   5.484700e+10
# Research And Development                            2.991500e+10
# Selling General And Administration                  2.493200e+10
# Gross Profit                                        1.691480e+11
# Cost Of Revenue                                     2.141370e+11
# Total Revenue                                       3.832850e+11
# Operating Revenue                                   3.832850e+11
#
#                                                       2022-09-30  \
# Tax Effect Of Unusual Items                         0.000000e+00
# Tax Rate For Calcs                                  1.620000e-01
# Normalized EBITDA                                   1.305410e+11
# Net Income From Continuing Operation Net Minori...  9.980300e+10
# Reconciled Depreciation                             1.110400e+10
# Reconciled Cost Of Revenue                          2.235460e+11
# EBITDA                                              1.305410e+11
# EBIT                                                1.194370e+11
# Net Interest Income                                -1.060000e+08
# Interest Expense                                    2.931000e+09
# Interest Income                                     2.825000e+09
# Normalized Income                                   9.980300e+10
# Net Income From Continuing And Discontinued Ope...  9.980300e+10
# Total Expenses                                      2.748910e+11
# Total Operating Income As Reported                  1.194370e+11
# Diluted Average Shares                              1.632582e+10
# Basic Average Shares                                1.621596e+10
# Diluted EPS                                         6.110000e+00
# Basic EPS                                           6.150000e+00
# Diluted NI Availto Com Stockholders                 9.980300e+10
# Net Income Common Stockholders                      9.980300e+10
# Net Income                                          9.980300e+10
# Net Income Including Noncontrolling Interests       9.980300e+10
# Net Income Continuous Operations                    9.980300e+10
# Tax Provision                                       1.930000e+10
# Pretax Income                                       1.191030e+11
# Other Income Expense                               -3.340000e+08
# Other Non Operating Income Expenses                -3.340000e+08
# Net Non Operating Interest Income Expense          -1.060000e+08
# Interest Expense Non Operating                      2.931000e+09
# Interest Income Non Operating                       2.825000e+09
# Operating Income                                    1.194370e+11
# Operating Expense                                   5.134500e+10
# Research And Development                            2.625100e+10
# Selling General And Administration                  2.509400e+10
# Gross Profit                                        1.707820e+11
# Cost Of Revenue                                     2.235460e+11
# Total Revenue                                       3.943280e+11
# Operating Revenue                                   3.943280e+11
#
#                                                       2021-09-30    2020-09-30
# Tax Effect Of Unusual Items                         0.000000e+00           NaN
# Tax Rate For Calcs                                  1.330000e-01           NaN
# Normalized EBITDA                                   1.231360e+11           NaN
# Net Income From Continuing Operation Net Minori...  9.468000e+10           NaN
# Reconciled Depreciation                             1.128400e+10           NaN
# Reconciled Cost Of Revenue                          2.129810e+11           NaN
# EBITDA                                              1.231360e+11           NaN
# EBIT                                                1.118520e+11           NaN
# Net Interest Income                                 1.980000e+08  8.900000e+08
# Interest Expense                                    2.645000e+09  2.873000e+09
# Interest Income                                     2.843000e+09  3.763000e+09
# Normalized Income                                   9.468000e+10           NaN
# Net Income From Continuing And Discontinued Ope...  9.468000e+10           NaN
# Total Expenses                                      2.568680e+11           NaN
# Total Operating Income As Reported                  1.089490e+11           NaN
# Diluted Average Shares                              1.686492e+10           NaN
# Basic Average Shares                                1.670127e+10           NaN
# Diluted EPS                                         5.610000e+00           NaN
# Basic EPS                                           5.670000e+00           NaN
# Diluted NI Availto Com Stockholders                 9.468000e+10           NaN
# Net Income Common Stockholders                      9.468000e+10           NaN
# Net Income                                          9.468000e+10           NaN
# Net Income Including Noncontrolling Interests       9.468000e+10           NaN
# Net Income Continuous Operations                    9.468000e+10           NaN
# Tax Provision                                       1.452700e+10           NaN
# Pretax Income                                       1.092070e+11           NaN
# Other Income Expense                                6.000000e+07           NaN
# Other Non Operating Income Expenses                 6.000000e+07           NaN
# Net Non Operating Interest Income Expense           1.980000e+08  8.900000e+08
# Interest Expense Non Operating                      2.645000e+09  2.873000e+09
# Interest Income Non Operating                       2.843000e+09  3.763000e+09
# Operating Income                                    1.089490e+11           NaN
# Operating Expense                                   4.388700e+10           NaN
# Research And Development                            2.191400e+10           NaN
# Selling General And Administration                  2.197300e+10           NaN
# Gross Profit                                        1.528360e+11           NaN
# Cost Of Revenue                                     2.129810e+11           NaN
# Total Revenue                                       3.658170e+11           NaN
# Operating Revenue                                   3.658170e+11           NaN

# %%
#Ebitda forecast

ending_ebitda = income_statement.loc['EBITDA'].iloc[0]
beginning_ebitda = income_statement.loc['EBITDA'].iloc[len(income_statement.columns)-1]
beginning_ebitda

ebitda_cagr = (ending_ebitda/beginning_ebitda)**(1/len(income_statement.columns)) - 1
ebitda_cagr
# Out:
# np.float64(nan)

# %%
future_ebitda = ending_ebitda*(1+ebitda_cagr)**(5)
future_ebitda
# Out:
# np.float64(nan)

# %%
# Terminal Value - Perpetuity Growth

pg_tv = future_fcf*(1+growth_rate)/(wacc - growth_rate)
pg_tv
# Out:
# np.float64(6297772636594.28)

# %%
# Terminal Value - ebitda multiple

eb_tv = future_ebitda * ev_to_ebitda
eb_tv
# Out:
# np.float64(nan)

# %%
pg_tv - eb_tv
# Out:
# np.float64(nan)

# %%
# Present Value of FCF, TV and Enterprise Value

projected_cash_flows = []
for year in range(1, 5):
    projected_fcf = ending_fcf*(1+fcf_cagr)**year
    projected_cash_flows.append(projected_fcf)

pv_fcf = 0
for year, fcf in enumerate(projected_cash_flows, start = 1):
    pv = fcf / (1+wacc)**(year+1)
    pv_fcf += pv

tv = (projected_cash_flows[-1]*(1+growth_rate))/(wacc - growth_rate)
tv

pv_tv = tv/((1+growth_rate)**5)
pv_tv

ev = pv_fcf+pv_tv
ev
# Out:
# np.float64(5840805189004.351)

# %%
#Calculate Equity

balance_sheet = ticker.balance_sheet
balance_sheet
cash_and_cash_equivalents = balance_sheet.loc['Cash And Cash Equivalents'].iloc[0]
cash_and_cash_equivalents

total_debt = balance_sheet.loc['Total Debt'].iloc[0]
total_debt

equity_value = ev + cash_and_cash_equivalents - total_debt
equity_value
# Out:
# np.float64(5764119189004.351)

# %%
# Shares Outstanding
shares_outstanding = ticker.info['sharesOutstanding']
shares_outstanding

share_price = equity_value / shares_outstanding
share_price
# Out:
# np.float64(388.4072692596211)

# %%
type(ticker)
# Out:
# yfinance.ticker.Ticker
